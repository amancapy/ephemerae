# %%
from scipy.io import loadmat
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import mode
import random
from scipy.ndimage import rotate, zoom
from sklearn.preprocessing import PowerTransformer
import pickle
from tqdm import tqdm
from multiprocessing import Pool
import gc

import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import tensorflow as tf
from keras import models, layers, losses, optimizers, Model
from keras.utils import plot_model
# Out:
# 2023-11-19 17:07:12.233456: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-19 17:07:12.233489: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-19 17:07:12.233524: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
gc.collect()
# Out:
# 0

# %%
pickles = [pickle.load(open(f"../data/pickles/{i}.pkl", "rb")) for i in range(9)]
targets = set([pickles[0][i][2] for i in range(len(pickles[0]))])

targets = list(targets)
targets = {target: [[0 if i != j else 1 for i in range(len(targets))]] for j, target in enumerate(targets)}

pickles = [item for sublist in pickles for item in sublist if item[2] in targets]
pickles = sorted(pickles, key=lambda x: x[2])

trains, tests = [pickles[i] for i in range(len(pickles)) if i % 6 != 0], [pickles[i] for i in range(len(pickles)) if i % 6 == 0]

train_x = np.array([train[0] for train in trains])
train_y = np.array([train[2] for train in trains])

test_x = [test[0] for test in tests]
test_y = [test[2] for test in tests]

print(len(pickles), len(train_x), len(train_y), len(test_x), len(test_y))

del pickles, trains, tests
# Out:
# 3240 2700 2700 540 540

# %%
def get_sample(train=True):
    x, y = ((train_x, train_y) if train else (test_x, test_y))
    
    i = random.randint(0, len(x) - 1)

    scan, target = x[i], y[i]
    scan = np.pad(scan, ((0, 0), (2, 1), (7, 6)), constant_values=scan.min())
    
    # scan = rotate(scan, random.randint(-5, 5), axes=(0, 1), order=0, reshape=False, mode="constant", cval=-1, prefilter=False)
    # scan = rotate(scan, random.randint(-5, 5), axes=(1, 2), order=0, reshape=False, mode="constant", cval=-1, prefilter=False)
    # scan = rotate(scan, random.randint(-5, 5), axes=(2, 0), order=0, reshape=False, mode="constant", cval=-1, prefilter=False)

    scan = np.expand_dims(scan, -1)
    
    target = targets[target]

    return scan, target

# %%
# %matplotlib widget

def plot_scan(scan, _3d=True):
    scan, target = scan
    scan = (scan - scan.min()) / (scan.max() - scan.min())
    
    voxels = scan[scan != scan.min()]
    indices = np.where(scan != scan.min())

    if _3d:
        fig = plt.figure()
        ax = fig.add_subplot(111, projection="3d")
        ax.set_xticks([]) or ax.set_yticks([]) or ax.set_zticks([])
        ax.set_title(target)
        ax.scatter(indices[0], indices[1], indices[2], c=voxels, alpha=voxels, cmap="twilight", s=30, marker="s")
        plt.setp(ax.spines.values(), color=(1, 1, 1))
        plt.show()

    w = 5
    fig, ax = plt.subplots(w, w, constrained_layout=True)
    fig.dpi = 100
    bg_color = (225 / 255, 216 / 255, 226 / 255)
    fig.set_facecolor(bg_color)

    for j in range(w * w):
        ax[(j - j % w) // w, j % w].imshow(scan[j % scan.shape[0]], vmin=0, vmax=1, cmap="twilight")
        ax[(j - j % w) // w, j % w].set_xticks([])
        ax[(j - j % w) // w, j % w].set_yticks([])
        plt.setp(ax[(j - j % w) // w, j % w].spines.values(), color=bg_color)

    plt.show()

# %%
plot_scan(get_sample())
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def get_batch(batch_size=32, train=True):
    
    samples = list(Pool(processes=8).imap(get_sample, [train] * batch_size))
    batch_x = [sample[0] for sample in samples]
    batch_y = [sample[1] for sample in samples]

    return np.array(batch_x), np.array(batch_y)

# %%
def conv3d():
    layers_ = [
               layers.ZeroPadding3D(((5, 4), (0, 0), (0, 0))),
               layers.Conv3D(8, 4, 1, padding="same", activation="relu"),
               layers.Conv3D(8, 4, (1, 2, 2), padding="same", activation="relu"),
               layers.Conv3D(16, 4, 2, padding="same", activation="relu"),
               layers.Conv3D(16, 4, 1, padding="same", activation="relu"),
               layers.Conv3D(32, 4, 2, padding="same", activation="relu"),
               layers.Conv3D(32, 4, 1, padding="same", activation="relu"),
               layers.Conv3D(64, 4, 2, padding="same", activation="relu"),
               layers.Conv3D(64, 4, 1, padding="same", activation="relu"),
               layers.Conv3D(128, 4, 1, padding="same", activation="relu"),
               layers.Conv3D(128, 4, 2, padding="same", activation="relu"),
               layers.Flatten(),
               layers.Dense(256, activation="relu"),
               layers.Dense(128, activation="relu"),
               ]
    
    inputs = layers.Input((23, 64, 64, 1))
    x = layers_[0](inputs)

    for layer in layers_[1:]:
        x = layers.BatchNormalization()(x)
        x = layer(x)
        x = layers.Dropout(0.6)(x)
    x = layers.Dense(12, activation="softmax")(x)

    return Model(inputs=inputs, outputs=x)

# %%
BATCH_SIZE = 64

model = conv3d()

opt = optimizers.Adam(learning_rate=0.001)
loss = losses.CategoricalCrossentropy()

def train():
    model.compile(opt, loss)
    _ = open("../classification/main_cat_log.txt", "w")
    
    for i in range(1000):
        batch_x, batch_y = get_batch(BATCH_SIZE)
        batch_x, batch_y = tf.convert_to_tensor(batch_x, dtype=tf.dtypes.float32), tf.convert_to_tensor(batch_y, dtype=tf.dtypes.float32)
        batch_y = tf.squeeze(batch_y, axis=1)

        with tf.GradientTape() as tape:
            pred_y = model(batch_x)
            if i == 0:
                model.summary()

            batchloss = loss(batch_y, pred_y)
            grad = tape.gradient(batchloss, model.trainable_variables)
            opt.apply_gradients(zip(grad, model.trainable_variables))

            print(i, float(batchloss))
    
            log = open("../classification/main_cat_log.txt", "a+")
            log.write(f"{i} {batchloss}\n")
            log.close()

        if i % 100 == 0:
            batch_x, batch_y = get_batch(320, train=False)
            batch_y = tf.squeeze(batch_y, axis=1)
            model.evaluate(batch_x, batch_y, batch_size=1)

train()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 23, 64, 64, 1)]   0
#
#  zero_padding3d (ZeroPaddin  (None, 32, 64, 64, 1)     0
#  g3D)
#
#  batch_normalization (Batch  (None, 32, 64, 64, 1)     4
#  Normalization)
#
#  conv3d (Conv3D)             (None, 32, 64, 64, 8)     520
#
#  dropout (Dropout)           (None, 32, 64, 64, 8)     0
#
#  batch_normalization_1 (Bat  (None, 32, 64, 64, 8)     32
#  chNormalization)
#
#  conv3d_1 (Conv3D)           (None, 32, 32, 32, 8)     4104
#
#  dropout_1 (Dropout)         (None, 32, 32, 32, 8)     0
#
#  batch_normalization_2 (Bat  (None, 32, 32, 32, 8)     32
#  chNormalization)
#
#  conv3d_2 (Conv3D)           (None, 16, 16, 16, 16)    8208
#
#  dropout_2 (Dropout)         (None, 16, 16, 16, 16)    0
#
#  batch_normalization_3 (Bat  (None, 16, 16, 16, 16)    64
#  chNormalization)
#
#  conv3d_3 (Conv3D)           (None, 16, 16, 16, 16)    16400
#
#  dropout_3 (Dropout)         (None, 16, 16, 16, 16)    0
#
#  batch_normalization_4 (Bat  (None, 16, 16, 16, 16)    64
#  chNormalization)
#
#  conv3d_4 (Conv3D)           (None, 8, 8, 8, 32)       32800
#
#  dropout_4 (Dropout)         (None, 8, 8, 8, 32)       0
#
#  batch_normalization_5 (Bat  (None, 8, 8, 8, 32)       128
#  chNormalization)
#
#  conv3d_5 (Conv3D)           (None, 8, 8, 8, 32)       65568
#
#  dropout_5 (Dropout)         (None, 8, 8, 8, 32)       0
#
#  batch_normalization_6 (Bat  (None, 8, 8, 8, 32)       128
#  chNormalization)
#
#  conv3d_6 (Conv3D)           (None, 4, 4, 4, 64)       131136
#
#  dropout_6 (Dropout)         (None, 4, 4, 4, 64)       0
#
#  batch_normalization_7 (Bat  (None, 4, 4, 4, 64)       256
#  chNormalization)
#
#  conv3d_7 (Conv3D)           (None, 4, 4, 4, 64)       262208
#
#  dropout_7 (Dropout)         (None, 4, 4, 4, 64)       0
#
#  batch_normalization_8 (Bat  (None, 4, 4, 4, 64)       256
#  chNormalization)
#
#  conv3d_8 (Conv3D)           (None, 4, 4, 4, 128)      524416
#
#  dropout_8 (Dropout)         (None, 4, 4, 4, 128)      0
#
#  batch_normalization_9 (Bat  (None, 4, 4, 4, 128)      512
#  chNormalization)
#
#  conv3d_9 (Conv3D)           (None, 2, 2, 2, 128)      1048704
#
#  dropout_9 (Dropout)         (None, 2, 2, 2, 128)      0
#
#  batch_normalization_10 (Ba  (None, 2, 2, 2, 128)      512
#  tchNormalization)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dropout_10 (Dropout)        (None, 1024)              0
#
#  batch_normalization_11 (Ba  (None, 1024)              4096
#  tchNormalization)
#
#  dense (Dense)               (None, 256)               262400
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  batch_normalization_12 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_12 (Dropout)        (None, 128)               0
#
#  dense_2 (Dense)             (None, 12)                1548
#
# =================================================================
# Total params: 2398016 (9.15 MB)
# Trainable params: 2394462 (9.13 MB)
# Non-trainable params: 3554 (13.88 KB)
# _________________________________________________________________
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7fefdffe31f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7fefdffe31f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 0 2.484832763671875
# 320/320 [==============================] - 2s 5ms/step - loss: 2.4877
# 1 2.4812021255493164
# 2 2.684939384460449
# 3 2.487338066101074
# 4 2.481700897216797
# 5 2.486431360244751
# 6 2.483707904815674
# 7 2.4826107025146484
# 8 2.482675552368164
# 9 2.492877960205078
# 10 2.485384225845337
# 11 2.4848997592926025
# 12 2.49288010597229
# 13 2.4729230403900146
# 14 2.4950313568115234
# 15 2.482222080230713
# 16 2.488671064376831
# 17 2.4903407096862793
# 18 2.4783072471618652
# 19 2.4955241680145264
# 20 2.4864864349365234
# 21 2.4872336387634277
# 22 2.485713005065918
# 23 2.4834744930267334
# 24 2.4948761463165283
# 25 2.4720263481140137
# 26 2.4845833778381348
# 27 2.4816389083862305
# 28 2.4708786010742188
# 29 2.4814364910125732
# 30 2.4813835620880127
# 31 2.490182399749756
# 32 2.480501174926758
# 33 2.5014796257019043
# 34 2.500077724456787
# 35 2.4965457916259766
# 36 2.490394115447998
# 37 2.4810526371002197
# 38 2.4804983139038086
# 39 2.4868412017822266
# 40 2.4737796783447266
# 41 2.4913344383239746
# 42 2.4814186096191406
# 43 2.480675220489502
# 44 2.486179828643799
# 45 2.4733996391296387
# 46 2.47605037689209
# 47 2.492759943008423
# 48 2.4808783531188965
# 49 2.487157106399536
# 50 2.4868013858795166
# 51 2.4875144958496094
# 52 2.480858564376831
# 53 2.4879262447357178
# 54 2.482563018798828
# 55 2.4910573959350586
# 56 2.5145111083984375
# 57 2.4786791801452637
# 58 2.4885520935058594
# 59 2.4875965118408203
# 60 2.481616973876953
# 61 2.482449531555176
# 62 2.4893598556518555
# 63 2.48142147064209
# 64 2.4829652309417725
# 65 2.486009120941162
# 66 2.479604482650757
# 67 2.4848129749298096
# 68 2.4956228733062744
# 69 2.4762041568756104
# 70 2.4913339614868164
# 71 2.4809627532958984
# 72 2.4807400703430176
# 575 2.486301898956299
# 576 2.4845917224884033
# 577 2.4830098152160645
# 578 2.4861693382263184
# 579 2.4860479831695557
# 580 2.487011194229126
# 581 2.483497381210327
# 582 2.486543655395508
# 583 2.4833242893218994
# 584 2.48410701751709
# 585 2.4878005981445312
# 586 2.484707832336426
# 587 2.4834742546081543
# 588 2.4812214374542236
# 589 2.4846222400665283
# 590 2.4875478744506836
# 591 2.4868435859680176
# 592 2.4842166900634766
# 593 2.48134708404541
# 594 2.486090898513794
# 595 2.4867935180664062
# 596 2.4867208003997803
# 597 2.4858522415161133
# 598 2.4838509559631348
# 599 2.488340377807617
# 600 2.488034725189209
# 320/320 [==============================] - 2s 6ms/step - loss: 2.4843
# 601 2.484764814376831
# 602 2.4827418327331543
# 603 2.4895617961883545
# 604 2.486330032348633
# 605 2.486793041229248
# 606 2.4883759021759033
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /home/aman/pythonprojects/ephemerae/classification/main_cat.ipynb Cell 9 line 3
#      <a href='vscode-notebook-cell:/home/aman/pythonprojects/ephemerae/classification/main_cat.ipynb#X11sZmlsZQ%3D%3D?line=33'>34</a>             batch_y = tf.squeeze(batch_y, axis=1)
#      <a href='vscode-notebook-cell:/home/aman/pythonprojects/ephemerae/classification/main_cat.ipynb#X11sZmlsZQ%3D%3D?line=34'>35</a>             model.evaluate(batch_x, batch_y, batch_size=1)
# ---> <a href='vscode-notebook-cell:/home/aman/pythonprojects/ephemerae/classification/main_cat.ipynb#X11sZmlsZQ%3D%3D?line=36'>37</a> train()
#
# /home/aman/pythonprojects/ephemerae/classification/main_cat.ipynb Cell 9 line 2
#      <a href='vscode-notebook-cell:/home/aman/pythonprojects/ephemerae/classification/main_cat.ipynb#X11sZmlsZQ%3D%3D?line=19'>20</a>     model.summary()
#      <a href='vscode-notebook-cell:/home/aman/pythonprojects/ephemerae/classification/main_cat.ipynb#X11sZmlsZQ%3D%3D?line=21'>22</a> batchloss = loss(batch_y, pred_y)
# ---> <a href='vscode-notebook-cell:/home/aman/pythonprojects/ephemerae/classification/main_cat.ipynb#X11sZmlsZQ%3D%3D?line=22'>23</a> grad = tape.gradient(batchloss, model.trainable_variables)
#      <a href='vscode-notebook-cell:/home/aman/pythonprojects/ephemerae/classification/main_cat.ipynb#X11sZmlsZQ%3D%3D?line=23'>24</a> opt.apply_gradients(zip(grad, model.trainable_variables))
#      <a href='vscode-notebook-cell:/home/aman/pythonprojects/ephemerae/classification/main_cat.ipynb#X11sZmlsZQ%3D%3D?line=25'>26</a> print(i, float(batchloss))
#
# File ~/miniconda3/envs/ephemerai/lib/python3.9/site-packages/tensorflow/python/eager/backprop.py:1065, in GradientTape.gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1059   output_gradients = (
#    1060       composite_tensor_gradient.get_flat_tensors_for_gradients(
#    1061           output_gradients))
#    1062   output_gradients = [None if x is None else ops.convert_to_tensor(x)
#    1063                       for x in output_gradients]
# -> 1065 flat_grad = imperative_grad.imperative_grad(
#    1066     self._tape,
#    1067     flat_targets,
#    1068     flat_sources,
#    1069     output_gradients=output_gradients,
#    1070     sources_raw=flat_sources_raw,
#    1071     unconnected_gradients=unconnected_gradients)
#    1073 if not self._persistent:
#    1074   # Keep track of watched variables before setting tape to None
#    1075   self._watched_variables = self._tape.watched_variables()
#
# File ~/miniconda3/envs/ephemerai/lib/python3.9/site-packages/tensorflow/python/eager/imperative_grad.py:67, in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      63 except ValueError:
#      64   raise ValueError(
#      65       "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
# ---> 67 return pywrap_tfe.TFE_Py_TapeGradient(
#      68     tape._tape,  # pylint: disable=protected-access
#      69     target,
#      70     sources,
#      71     output_gradients,
#      72     sources_raw,
#      73     compat.as_str(unconnected_gradients.value))
#
# File ~/miniconda3/envs/ephemerai/lib/python3.9/site-packages/tensorflow/python/eager/backprop.py:147, in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     145     gradient_name_scope += forward_pass_name_scope + "/"
#     146   with ops.name_scope(gradient_name_scope):
# --> 147     return grad_fn(mock_op, *out_grads)
#     148 else:
#     149   return grad_fn(mock_op, *out_grads)
#
# File ~/miniconda3/envs/ephemerai/lib/python3.9/site-packages/tensorflow/python/ops/nn_grad.py:156, in _Conv3DGrad(op, grad)
#     153 data_format = op.get_attr("data_format").decode()
#     154 shape_0, shape_1 = array_ops.shape_n([op.inputs[0], op.inputs[1]])
#     155 return [
# --> 156     nn_ops.conv3d_backprop_input_v2(
#     157         shape_0,
#     158         op.inputs[1],
#     159         grad,
#     160         dilations=op.get_attr("dilations"),
#     161         strides=op.get_attr("strides"),
#     162         padding=op.get_attr("padding"),
#     163         data_format=data_format),
#     164     nn_ops.conv3d_backprop_filter_v2(
#     165         op.inputs[0],
#     166         shape_1,
#     167         grad,
#     168         dilations=op.get_attr("dilations"),
#     169         strides=op.get_attr("strides"),
#     170         padding=op.get_attr("padding"),
#     171         data_format=data_format)
#     172 ]
#
# File ~/miniconda3/envs/ephemerai/lib/python3.9/site-packages/tensorflow/python/ops/gen_nn_ops.py:2727, in conv3d_backprop_input_v2(input_sizes, filter, out_backprop, strides, padding, data_format, dilations, name)
#    2725   return _result
#    2726 except _core._NotOkStatusException as e:
# -> 2727   _ops.raise_from_not_ok_status(e, name)
#    2728 except _core._FallbackException:
#    2729   pass
#
# File ~/miniconda3/envs/ephemerai/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:5888, in raise_from_not_ok_status(e, name)
#    5886 def raise_from_not_ok_status(e, name) -> NoReturn:
#    5887   e.message += (" name: " + str(name if name is not None else ""))
# -> 5888   raise core._status_to_exception(e) from None
#
# ResourceExhaustedError: {{function_node __wrapped__Conv3DBackpropInputV2_device_/job:localhost/replica:0/task:0/device:GPU:0}} OOM when allocating tensor with shape[64,8,32,64,64] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:Conv3DBackpropInputV2] name:

# %%
with open("../classification/main_cat_log.txt") as f:
    f = f.read().splitlines()
    losses = [float(item.split()[1]) for item in f if item]

    plt.clf()
    plt.plot(losses, lw=0.5)
    plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
